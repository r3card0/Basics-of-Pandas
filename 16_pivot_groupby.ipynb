# %% [markdown]
# # Pivot

# %% [markdown]
# ## Instalar librerias

# %%
# Instalar librerias
# !pip install --upgrade pandas

import pandas as pd
import numpy as np
import seaborn as sns
pd.__version__
# Out:
# ...
# '1.3.5'

# %% [markdown]
# ## Dar formato a los decimales

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# ## Crear DataFrame a partir de la libreria Seaborn
#
# Se crea una base de datos de un restaurante

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0        16.990 1.010  Female     No   Sun  Dinner     2
# 1        10.340 1.660    Male     No   Sun  Dinner     3
# 2        21.010 3.500    Male     No   Sun  Dinner     3
# 3        23.680 3.310    Male     No   Sun  Dinner     2
# 4        24.590 3.610  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2
# 242      17.820 1.750    Male     No   Sat  Dinner     2
# 243      18.780 3.000  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Agrupar por sex y time y calcular el promedio de total_bill

# %%
df.groupby(['sex','time'])[['total_bill']].mean()
# Out:
#                total_bill
# sex    time
# Male   Lunch       18.048
#        Dinner      21.461
# Female Lunch       16.339
#        Dinner      19.213

# %% [markdown]
# Borrar indices y hacerlos columnas

# %%
df_gp = df.groupby(['sex','time'])[['total_bill']].mean().reset_index()
df_gp
# Out:
#       sex    time  total_bill
# 0    Male   Lunch      18.048
# 1    Male  Dinner      21.461
# 2  Female   Lunch      16.339
# 3  Female  Dinner      19.213

# %% [markdown]
# ## Aplicar tabla dinámica
#
# Hizo como un transpose :P
#
# Pivot table calcula el promedio de Lunch para Male y Female y Dinner igual

# %% [markdown]
# ![](https://pandas-docs.github.io/pandas-docs-travis/_images/reshaping_pivot.png)

# %%
df_gp.pivot_table(values='total_bill', index='sex',columns='time')
# Out:
# time    Lunch  Dinner
# sex
# Male   18.048  21.461
# Female 16.339  19.213

# %%
# otra forma que calcula lo mismo promedio
df.pivot_table(values='total_bill', index='sex',columns='time')
# Out:
# time    Lunch  Dinner
# sex
# Male   18.048  21.461
# Female 16.339  19.213

# %% [markdown]
# ### Ahora a calcular la mediana

# %%
df.pivot_table(values='total_bill', index='sex',columns='time', aggfunc=np.median)
# Out:
# time    Lunch  Dinner
# sex
# Male   16.580  19.630
# Female 13.420  17.190

# %% [markdown]
# ### Calcular mediana y desviación estandar std

# %%
df.pivot_table(values='total_bill', index='sex',columns='time', aggfunc=[np.median,np.std])
# Out:
#        median          std
# time    Lunch Dinner Lunch Dinner
# sex
# Male   16.580 19.630 7.953  9.461
# Female 13.420 17.190 7.501  8.202

# %% [markdown]
# ### Deshace las categorias para convertiras en filas

# %%
# 1. Guardar el codigo anterior en una variable
df_pivot = df.pivot_table(values='total_bill', index='sex',columns='time', aggfunc=[np.median,np.std])
df_pivot
# Out:
#        median          std
# time    Lunch Dinner Lunch Dinner
# sex
# Male   16.580 19.630 7.953  9.461
# Female 13.420 17.190 7.501  8.202

# %%
# 2. Deshacer las categorias y convertirlas en filas
df_pivot.unstack()
# Out:
#         time    sex
# median  Lunch   Male     16.580
#                 Female   13.420
#         Dinner  Male     19.630
#                 Female   17.190
# std     Lunch   Male      7.953
#                 Female    7.501
#         Dinner  Male      9.461
#                 Female    8.202
# dtype: float64

# %%
# 3. Convertir a DataFrame
df_pivot.unstack().reset_index()
# Out:
#   level_0    time     sex      0
# 0  median   Lunch    Male 16.580
# 1  median   Lunch  Female 13.420
# 2  median  Dinner    Male 19.630
# 3  median  Dinner  Female 17.190
# 4     std   Lunch    Male  7.953
# 5     std   Lunch  Female  7.501
# 6     std  Dinner    Male  9.461
# 7     std  Dinner  Female  8.202
